# %% [markdown]
# <a href="https://colab.research.google.com/github/Dei-gratia/Android-CandyCodedApplication/blob/master/Machine%20Learning%20%26%20Deep%20Learning%20Projects%20for%20Beginners/Dissertation_results_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'Algorithm': ['IQR_MMT', 'LR_MMT', 'LRR_MMT', 'MAD_MMT', 'THR_MMT', 'BGWO_VMP', 'EML_IGWO'],
    'EC': [188.86, 163.15, 163.15, 184.88, 191.73, 136.38, 130.49],
    'NM': [26476, 27632, 27632, 26292, 26634, 23815, 3851],
    'SLAV': [3.15, 4.63, 4.63, 3.31, 3.24, 2.8, 0.107],
    'ESV': [0.005949, 0.007554, 0.007554, 0.00612, 0.006212, 0.003819, 0.00014],
    'PDM': [6, 8, 8, 7, 7, 4, 1.2]
}

df = pd.DataFrame(data)
df
# Out:
#   Algorithm      EC     NM   SLAV       ESV  PDM
# 0   IQR_MMT  188.86  26476  3.150  0.005949  6.0
# 1    LR_MMT  163.15  27632  4.630  0.007554  8.0
# 2   LRR_MMT  163.15  27632  4.630  0.007554  8.0
# 3   MAD_MMT  184.88  26292  3.310  0.006120  7.0
# 4   THR_MMT  191.73  26634  3.240  0.006212  7.0
# 5  BGWO_VMP  136.38  23815  2.800  0.003819  4.0
# 6  EML_IGWO  130.49   3851  0.107  0.000140  1.2

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))
for column in df.columns[1:]:
    plt.plot(df['Algorithm'], df[column], marker='o', label=column)

plt.title('Algorithm Performance Metrics')
plt.xlabel('Algorithm')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(14, 8))
df_melted = df.melt(id_vars=['Algorithm'], var_name='Metric', value_name='Value')
sns.boxplot(x='Metric', y='Value', data=df_melted, palette='Set3')
plt.title('Box Plot of Performance Metrics')
plt.show()
# Out:
# <ipython-input-4-0e87243c9941>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Metric', y='Value', data=df_melted, palette='Set3')

# %%
from math import pi

# Prepare the data
categories = list(df.columns[1:])
N = len(categories)

# Create Radar chart
for i in range(len(df)):
    values = df.iloc[i, 1:].values.flatten().tolist()
    values += values[:1]
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    ax = plt.subplot(111, polar=True)
    plt.xticks(angles[:-1], categories, color='grey', size=8)
    ax.plot(angles, values, linewidth=1, linestyle='solid', label=df['Algorithm'][i])
    ax.fill(angles, values, alpha=0.1)

plt.title('Radar Chart of Algorithms')
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

# Line Chart
for column in df.columns[1:]:
    axes[0, 0].plot(df['Algorithm'], df[column], marker='o', label=column)
axes[0, 0].set_title('Line Chart of Performance Metrics')
axes[0, 0].set_xlabel('Algorithm')
axes[0, 0].set_ylabel('Values')
axes[0, 0].legend()
axes[0, 0].grid(True)
axes[0, 0].tick_params(labelrotation=45)

# Box Plot
df_melted = df.melt(id_vars=['Algorithm'], var_name='Metric', value_name='Value')
sns.boxplot(x='Metric', y='Value', data=df_melted, palette='Set3', ax=axes[0, 1])
axes[0, 1].set_title('Box Plot of Performance Metrics')

# Radar Chart
for i in range(len(df)):
    values = df.iloc[i, 1:].values.flatten().tolist()
    values += values[:1]
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]
    axes[1, 0] = plt.subplot(223, polar=True)
    axes[1, 0].plot(angles, values, linewidth=1, linestyle='solid', label=df['Algorithm'][i])
    axes[1, 0].fill(angles, values, alpha=0.1)
axes[1, 0].set_title('Radar Chart of Algorithms')
axes[1, 0].legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# <ipython-input-6-6be9c4a1d3a6>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Metric', y='Value', data=df_melted, palette='Set3', ax=axes[0, 1])
# <ipython-input-6-6be9c4a1d3a6>:24: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   axes[1, 0] = plt.subplot(223, polar=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data from the provided image
data = {
    'Algorithm': ['IQR_MMT', 'LR_MMT', 'LRR_MMT', 'MAD_MMT', 'THR_MMT', 'BGWO_VMP', 'EML_MPACS', 'EML_IGWO'],
    'EC (kWh)': [188.86, 163.15, 163.15, 184.88, 191.73, 143.38, 138.99, 130.49],
    'NM *10^3': [26.476, 27.632, 27.632, 26.292, 26.634, 23.815, 2.881, 2.581],
    'SLAV *10E-3': [3.15, 4.63, 4.63, 3.31, 3.24, 2.8, 0.09, 0.076],
    'ESV': [0.00594909, 0.007553845, 0.007553845, 0.006119528, 0.006212052, 0.00401464, 0.000125091, 9.91724E-05],
    'PDM % *10^-2': [6, 8, 8, 7, 7, 4, 1.4, 1.2]
}

df = pd.DataFrame(data)

# Plot line graphs for each metric
plt.figure(figsize=(18, 10))

# Plot for EC (kWh)
plt.subplot(2, 3, 1)
plt.plot(df['Algorithm'], df['EC (kWh)'], marker='o', label='EC (kWh)')
plt.title('EC (kWh) Comparison')
plt.xlabel('Algorithm')
plt.ylabel('EC (kWh)')
plt.legend()
plt.grid(True)

# Plot for NM *10^3
plt.subplot(2, 3, 2)
plt.plot(df['Algorithm'], df['NM *10^3'], marker='o', label='NM *10^3')
plt.title('NM *10^3 Comparison')
plt.xlabel('Algorithm')
plt.ylabel('NM *10^3')
plt.legend()
plt.grid(True)

# Plot for SLAV *10E-3
plt.subplot(2, 3, 3)
plt.plot(df['Algorithm'], df['SLAV *10E-3'], marker='o', label='SLAV *10E-3')
plt.title('SLAV *10E-3 Comparison')
plt.xlabel('Algorithm')
plt.ylabel('SLAV *10E-3')
plt.legend()
plt.grid(True)

# Plot for ESV
plt.subplot(2, 3, 4)
plt.plot(df['Algorithm'], df['ESV'], marker='o', label='ESV')
plt.title('ESV Comparison')
plt.xlabel('Algorithm')
plt.ylabel('ESV')
plt.legend()
plt.grid(True)

# Plot for PDM % *10^-2
plt.subplot(2, 3, 5)
plt.plot(df['Algorithm'], df['PDM % *10^-2'], marker='o', label='PDM % *10^-2')
plt.title('PDM % *10^-2 Comparison')
plt.xlabel('Algorithm')
plt.ylabel('PDM % *10^-2')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
data = {
    'Algorithm': ['IQR_MMT', 'LR_MMT', 'LRR_MMT', 'MAD_MMT', 'THR_MMT', 'BGWO_VMP', 'EML_MPACS', 'EML_IGWO'],
    'EC (kWh)': [188.86, 163.15, 163.15, 184.88, 191.73, 143.38, 138.99, 130.49],
    'NM *10^3': [26.476, 27.632, 27.632, 26.292, 26.634, 23.815, 2.881, 2.581],
    'SLAV *10E-3': [3.15, 4.63, 4.63, 3.31, 3.24, 2.8, 0.09, 0.076],
    'ESV': [0.00594909, 0.007553845, 0.007553845, 0.006119528, 0.006212052, 0.00401464, 0.000125091, 9.91724E-05],
    'PDM % *10^-2': [6, 8, 8, 7, 7, 4, 1.4, 1.2]
}

df = pd.DataFrame(data)
plt.figure(figsize=(10, 8))
correlation_matrix = df.iloc[:, 1:].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Performance Metrics')
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind

# Data from the provided image
data = {
    'Algorithm': ['IQR_MMT', 'LR_MMT', 'LRR_MMT', 'MAD_MMT', 'THR_MMT', 'BGWO_VMP', 'EML_MPACS', 'EML_IGWO'],
    'EC (kWh)': [188.86, 163.15, 163.15, 184.88, 191.73, 143.38, 138.99, 130.49],
    'NM *10^3': [26.476, 27.632, 27.632, 26.292, 26.634, 23.815, 2.881, 2.581],
    'SLAV *10E-3': [3.15, 4.63, 4.63, 3.31, 3.24, 2.8, 0.09, 0.076],
    'ESV': [0.00594909, 0.007553845, 0.007553845, 0.006119528, 0.006212052, 0.00401464, 0.000125091, 9.91724E-05],
    'PDM % *10^-2': [6, 8, 8, 7, 7, 4, 1.4, 1.2]
}

df = pd.DataFrame(data)

# Descriptive statistics
descriptive_stats = df.describe()
print("Descriptive Statistics:")
print(descriptive_stats)

# Efficiency ratios
efficiency_ratios = df.iloc[:, 1:].div(df.iloc[:, 1:].sum(axis=1), axis=0)
print("\nEfficiency Ratios:")
print(efficiency_ratios)

# Relative improvement (compared to the next best algorithm, BGWO_VMP)
relative_improvement = (df.iloc[-1, 1:] - df.iloc[5, 1:]) / df.iloc[5, 1:] * 100
print("\nRelative Improvement (compared to BGWO_VMP):")
print(relative_improvement)

# Effect sizes (Cohen's d)
def cohens_d(group1, group2):
    diff = np.mean(group1) - np.mean(group2)
    pooled_std = np.sqrt((np.std(group1, ddof=1) ** 2 + np.std(group2, ddof=1) ** 2) / 2)
    return diff / pooled_std

effect_sizes = {
    'EC (kWh)': cohens_d(df['EC (kWh)'], df['EC (kWh)']),
    'NM *10^3': cohens_d(df['NM *10^3'], df['NM *10^3']),
    'SLAV *10E-3': cohens_d(df['SLAV *10E-3'], df['SLAV *10E-3']),
    'ESV': cohens_d(df['ESV'], df['ESV']),
    'PDM % *10^-2': cohens_d(df['PDM % *10^-2'], df['PDM % *10^-2']),
}
print("\nEffect Sizes (Cohen's d):")
print(effect_sizes)
# Out:
# Descriptive Statistics:
#          EC (kWh)   NM *10^3  SLAV *10E-3       ESV  PDM % *10^-2
# count    8.000000   8.000000     8.000000  8.000000      8.000000
# mean   163.078750  20.492875     2.740750  0.004703      5.325000
# std     23.878283  11.026754     1.773221  0.003041      2.791697
# min    130.490000   2.581000     0.076000  0.000099      1.200000
# 25%    142.282500  18.581500     2.122500  0.003042      3.350000
# 50%    163.150000  26.384000     3.195000  0.006034      6.500000
# 75%    185.875000  26.883500     3.640000  0.006548      7.250000
# max    191.730000  27.632000     4.630000  0.007554      8.000000
#
# Efficiency Ratios:
#    EC (kWh)  NM *10^3  SLAV *10E-3           ESV  PDM % *10^-2
# 0  0.841277  0.117937     0.014032  2.650024e-05      0.026727
# 1  0.802037  0.135837     0.022761  3.713431e-05      0.039328
# 2  0.802037  0.135837     0.022761  3.713431e-05      0.039328
# 3  0.834717  0.118706     0.014944  2.762915e-05      0.031604
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Data from the provided image
data = {
    'Algorithm': ['IQR_MMT', 'LR_MMT', 'LRR_MMT', 'MAD_MMT', 'THR_MMT', 'BGWO_VMP', 'EML_MPACS', 'EML_IGWO'],
    'EC (kWh)': [188.86, 163.15, 163.15, 184.88, 191.73, 143.38, 138.99, 130.49],
    'NM *10^3': [26.476, 27.632, 27.632, 26.292, 26.634, 23.815, 2.881, 2.581],
    'SLAV *10E-3': [3.15, 4.63, 4.63, 3.31, 3.24, 2.8, 0.09, 0.076],
    'ESV': [0.00594909, 0.007553845, 0.007553845, 0.006119528, 0.006212052, 0.00401464, 0.000125091, 9.91724E-05],
    'PDM % *10^-2': [6, 8, 8, 7, 7, 4, 1.4, 1.2]
}

df = pd.DataFrame(data)

# Descriptive statistics
descriptive_stats = df.describe()

# Efficiency ratios
efficiency_ratios = df.iloc[:, 1:].div(df.iloc[:, 1:].sum(axis=1), axis=0)

# Relative improvement (compared to the next best algorithm, BGWO_VMP)
relative_improvement = (df.iloc[-1, 1:] - df.iloc[5, 1:]) / df.iloc[5, 1:] * 100

# Plotting Descriptive Statistics
plt.figure(figsize=(14, 8))
sns.boxplot(data=df.iloc[:, 1:], palette='Set3')
plt.title('Box Plot of Performance Metrics')
plt.show()

# Plotting Efficiency Ratios
efficiency_ratios.plot(kind='bar', figsize=(14, 8))
plt.title('Efficiency Ratios')
plt.ylabel('Ratio')
plt.show()

# Plotting Relative Improvement
relative_improvement.plot(kind='bar', figsize=(14, 8), color='green')
plt.title('Relative Improvement Compared to BGWO_VMP')
plt.ylabel('Improvement (%)')
plt.show()

# Effect sizes (Cohen's d)
def cohens_d(group1, group2):
    diff = np.mean(group1) - np.mean(group2)
    pooled_std = np.sqrt((np.std(group1, ddof=1) ** 2 + np.std(group2, ddof=1) ** 2) / 2)
    return diff / pooled_std

effect_sizes = {
    'EC (kWh)': cohens_d(df['EC (kWh)'], df['EC (kWh)']),
    'NM *10^3': cohens_d(df['NM *10^3'], df['NM *10^3']),
    'SLAV *10E-3': cohens_d(df['SLAV *10E-3'], df['SLAV *10E-3']),
    'ESV': cohens_d(df['ESV'], df['ESV']),
    'PDM % *10^-2': cohens_d(df['PDM % *10^-2'], df['PDM % *10^-2']),
}

effect_sizes_df = pd.DataFrame(list(effect_sizes.items()), columns=['Metric', 'Effect Size'])

# Plotting Effect Sizes
effect_sizes_df.plot(kind='bar', x='Metric', y='Effect Size', legend=False, figsize=(14, 8), color='purple')
plt.title('Effect Sizes (Cohen\'s d)')
plt.ylabel('Effect Size')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Data from the provided image
data = {
    'Algorithm': ['IQR_MMT', 'LR_MMT', 'LRR_MMT', 'MAD_MMT', 'THR_MMT', 'BGWO_VMP', 'EML_MPACS', 'EML_IGWO'],
    'EC (kWh)': [188.86, 163.15, 163.15, 184.88, 191.73, 143.38, 138.99, 130.49],
    'NM *10^3': [26.476, 27.632, 27.632, 26.292, 26.634, 23.815, 2.881, 2.581],
    'SLAV *10E-3': [3.15, 4.63, 4.63, 3.31, 3.24, 2.8, 0.09, 0.076],
    'ESV': [0.00594909, 0.007553845, 0.007553845, 0.006119528, 0.006212052, 0.00401464, 0.000125091, 9.91724E-05],
    'PDM % *10^-2': [6, 8, 8, 7, 7, 4, 1.4, 1.2]
}

df = pd.DataFrame(data)

# Descriptive statistics
descriptive_stats = df.describe()

# Efficiency ratios
efficiency_ratios = df.iloc[:, 1:].div(df.iloc[:, 1:].sum(axis=1), axis=0)

# Relative improvement (compared to the next best algorithm, BGWO_VMP)
relative_improvement = (df.iloc[-1, 1:] - df.iloc[5, 1:]) / df.iloc[5, 1:] * 100

# Plotting Line Graphs for Descriptive Statistics
plt.figure(figsize=(14, 8))
for column in df.columns[1:]:
    plt.plot(df['Algorithm'], df[column], marker='o', label=column)
plt.title('Line Plot of Performance Metrics')
plt.xlabel('Algorithm')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()

# Plotting Line Graphs for Efficiency Ratios
plt.figure(figsize=(14, 8))
efficiency_ratios.plot(kind='line', marker='o')
plt.title('Line Plot of Efficiency Ratios')
plt.xlabel('Algorithm')
plt.ylabel('Ratio')
plt.grid(True)
plt.show()

# Plotting Line Graphs for Relative Improvement
plt.figure(figsize=(14, 8))
relative_improvement.plot(kind='line', marker='o', color='green')
plt.title('Line Plot of Relative Improvement Compared to BGWO_VMP')
plt.xlabel('Metric')
plt.ylabel('Improvement (%)')
plt.grid(True)
plt.show()

# Plotting Line Graphs for Effect Sizes
def cohens_d(group1, group2):
    diff = np.mean(group1) - np.mean(group2)
    pooled_std = np.sqrt((np.std(group1, ddof=1) ** 2 + np.std(group2, ddof=1) ** 2) / 2)
    return diff / pooled_std

effect_sizes = {
    'EC (kWh)': cohens_d(df['EC (kWh)'], df['EC (kWh)']),
    'NM *10^3': cohens_d(df['NM *10^3'], df['NM *10^3']),
    'SLAV *10E-3': cohens_d(df['SLAV *10E-3'], df['SLAV *10E-3']),
    'ESV': cohens_d(df['ESV'], df['ESV']),
    'PDM % *10^-2': cohens_d(df['PDM % *10^-2'], df['PDM % *10^-2']),
}

effect_sizes_df = pd.DataFrame(list(effect_sizes.items()), columns=['Metric', 'Effect Size'])

effect_sizes_df.plot(kind='line', x='Metric', y='Effect Size', marker='o', legend=False, color='purple')
plt.title('Line Plot of Effect Sizes (Cohen\'s d)')
plt.xlabel('Metric')
plt.ylabel('Effect Size')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data
data = {
    "Algorithm": ["IQR_MMT", "LR_MMT", "LRR_MMT", "MAD_MMT", "THR_MMT", "BGWO_VMP", "EML_MPACS", "EML_IGWO"],
    "EC(kWh)": [188.86, 163.15, 163.15, 184.88, 191.73, 143.38, 138.99, 130.49],
    "NM *10^3": [26.476, 27.632, 27.632, 26.292, 26.634, 23.815, 2.881, 2.581],
    "SLAV *10E-3": [3.15, 4.63, 4.63, 3.31, 3.24, 2.8, 0.09, 0.076],
    "ESV": [0.00594909, 0.007553845, 0.007553845, 0.006119528, 0.006212052, 0.00401464, 0.000125091, 9.91724E-05],
    "PDM % *10^-2": [6, 8, 8, 7, 7, 4, 1.4, 1.2]
}

df = pd.DataFrame(data)
eml_igwo_row = df[df['Algorithm'] == 'EML_IGWO']

# Normalize the data
normalized_df = (df.iloc[:, 1:] - df.iloc[:, 1:].min()) / (df.iloc[:, 1:].max() - df.iloc[:, 1:].min())

# Calculate accuracy and efficiency for EML_IGWO
accuracy = 1 - np.abs((eml_igwo_row.iloc[:, 1:] - df.iloc[:, 1:].min()) / df.iloc[:, 1:].min())
efficiency = df.iloc[:, 1:].min() / eml_igwo_row.iloc[:, 1:]

# Plotting
fig, ax = plt.subplots(2, 1, figsize=(12, 10))

# Accuracy plot
ax[0].bar(accuracy.columns, accuracy.values[0] * 100)
ax[0].set_title('Accuracy Percentage for EML_IGWO')
ax[0].set_ylabel('Accuracy (%)')

# Efficiency plot
ax[1].bar(efficiency.columns, efficiency.values[0] * 100)
ax[1].set_title('Efficiency Percentage for EML_IGWO')
ax[1].set_ylabel('Efficiency (%)')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data from the provided image
data = {
    'Algorithm': ['IQR_MMT', 'LR_MMT', 'LRR_MMT', 'MAD_MMT', 'THR_MMT', 'BGWO_VMP', 'EML_MPACS', 'EML_IGWO'],
    'EC (kWh)': [188.86, 163.15, 163.15, 184.88, 191.73, 143.38, 138.99, 130.49],
    'NM *10^3': [26.476, 27.632, 27.632, 26.292, 26.634, 23.815, 2.881, 2.581],
    'SLAV *10E-3': [3.15, 4.63, 4.63, 3.31, 3.24, 2.8, 0.09, 0.076],
    'ESV': [0.00594909, 0.007553845, 0.007553845, 0.006119528, 0.006212052, 0.00401464, 0.000125091, 9.91724E-05],
    'PDM % *10^-2': [6, 8, 8, 7, 7, 4, 1.4, 1.2]
}

df = pd.DataFrame(data)

# Calculate Relative Improvement of EML_IGWO compared to EML_MPACS
eml_mpacs_values = df.iloc[6, 1:].values
eml_igwo_values = df.iloc[7, 1:].values

relative_improvement_eml_igwo_vs_eml_mpacs = (eml_mpacs_values - eml_igwo_values) / eml_mpacs_values * 100
relative_improvement_eml_igwo_vs_eml_mpacs_df = pd.DataFrame(relative_improvement_eml_igwo_vs_eml_mpacs, index=df.columns[1:], columns=['Improvement (%)'])

# Plotting the improvement percentage graph
plt.figure(figsize=(10, 6))
relative_improvement_eml_igwo_vs_eml_mpacs_df.plot(kind='bar', legend=False)
plt.title('Relative Improvement of EML_IGWO Compared to EML_MPACS')
plt.xlabel('Metrics')
plt.ylabel('Improvement (%)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data from the provided image
data = {
    'Algorithm': ['IQR_MMT', 'LR_MMT', 'LRR_MMT', 'MAD_MMT', 'THR_MMT', 'BGWO_VMP', 'EML_MPACS', 'EML_IGWO'],
    'EC (kWh)': [188.86, 163.15, 163.15, 184.88, 191.73, 143.38, 138.99, 130.49],
    'NM *10^3': [26.476, 27.632, 27.632, 26.292, 26.634, 23.815, 2.881, 2.581],
    'SLAV *10E-3': [3.15, 4.63, 4.63, 3.31, 3.24, 2.8, 0.09, 0.076],
    'ESV': [0.00594909, 0.007553845, 0.007553845, 0.006119528, 0.006212052, 0.00401464, 0.000125091, 9.91724E-05],
    'PDM % *10^-2': [6, 8, 8, 7, 7, 4, 1.4, 1.2]
}

df = pd.DataFrame(data)

# Calculate the relative improvement of EML_IGWO compared to EML_MPACS
relative_improvement_eml_igwo_vs_eml_mpacs = (df.iloc[-1, 1:] - df.iloc[-2, 1:]) / df.iloc[-2, 1:] * 100

# Plot the relative improvement
plt.figure(figsize=(10, 6))
relative_improvement_eml_igwo_vs_eml_mpacs.plot(kind='line', marker='o', color='blue')
plt.title('Relative Improvement of EML_IGWO Compared to EML_MPACS')
plt.xlabel('Metric')
plt.ylabel('Improvement (%)')
plt.grid(True)
plt.show()
